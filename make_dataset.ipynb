# %%
# importing libraries
import h5py
import scipy.io as io
import scipy.spatial
import PIL.Image as Image
import numpy as np
import os
import glob
from matplotlib import pyplot as plt
from scipy.ndimage.filters import gaussian_filter
import scipy
import json
from matplotlib import cm as CM
from image import *
from model import CSRNet
import torch
from tqdm import tqdm
# %matplotlib inline

# %%
#this is borrowed from GreenHolics Team
def gaussian_filter_density(gt):
    print (gt.shape)
    density = np.zeros(gt.shape, dtype=np.float32)
    gt_count = np.count_nonzero(gt)
    if gt_count == 0:
        return density

    pts = np.array(list(zip(np.nonzero(gt)[1], np.nonzero(gt)[0])))
    leafsize = 2048
    # build kdtree
    tree = scipy.spatial.KDTree(pts.copy(), leafsize=leafsize)
    # query kdtree
    distances, locations = tree.query(pts, k=4)

    print ('generate density...')
    for i, pt in enumerate(pts):
        pt2d = np.zeros(gt.shape, dtype=np.float32)
        pt2d[pt[1],pt[0]] = 1.
        if gt_count > 1:
            sigma = (distances[i][1]+distances[i][2]+distances[i][3])*0.1
        else:
            sigma = np.average(np.array(gt.shape))/2./2. #case: 1 point
        density += scipy.ndimage.filters.gaussian_filter(pt2d, sigma, mode='constant')
    print ('done.')
    return density

# %%
#setting the root to the Shanghai dataset you have downloaded
# change the root path as per your location of dataset
root = 'J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/'

# %%
#now generate the ShanghaiA's ground truth
part_A_train = os.path.join(root,'part_A_final/train_data/','images')
part_A_test = os.path.join(root,'part_A_final/test_data/','images')
part_B_train = os.path.join(root,'part_B_final/train_data/','images')
part_B_test = os.path.join(root,'part_B_final/test_data/','images')
path_sets = [part_A_train,part_A_test]

# %%
img_paths = []
for path in path_sets:
    for img_path in glob.glob(os.path.join(path, '*.jpg')):
        img_paths.append(img_path)

# %%
for img_path in img_paths:
    print (img_path)
    mat = io.loadmat(img_path.replace('.jpg','.mat').replace('images','ground-truth').replace('IMG_','GT_IMG_'))
    img= plt.imread(img_path)
    k = np.zeros((img.shape[0],img.shape[1]))
    gt = mat["image_info"][0,0][0,0][0]
    for i in range(0,len(gt)):
        if int(gt[i][1])<img.shape[0] and int(gt[i][0])<img.shape[1]:
            k[int(gt[i][1]),int(gt[i][0])]=1
    k = gaussian_filter_density(k)
    with h5py.File(img_path.replace('.jpg','.h5').replace('images','ground-truth'), 'w') as hf:
            hf['density'] = k

# %%
#now see a sample from ShanghaiA
plt.imshow(Image.open(img_paths[1]))
print('density --' )
print(k)
# Out:
# density --
# [[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#   0.0000000e+00 0.0000000e+00]
#  ...
#  [3.5245415e-05 3.9891562e-05 4.5005221e-05 ... 8.3316003e-08
#   7.9835857e-08 7.6443328e-08]
#  [3.3830602e-05 3.8291390e-05 4.3201180e-05 ... 7.5667948e-08
#   7.2507262e-08 6.9426157e-08]
#  [3.2372249e-05 3.6641646e-05 4.1340896e-05 ... 6.8670069e-08
#   6.5801693e-08 6.3005523e-08]]

# %%
gt_file = h5py.File(img_paths[0].replace('.jpg','.h5').replace('images','ground-truth'),'r')
groundtruth = np.asarray(gt_file['density'])
plt.imshow(groundtruth,cmap=CM.jet)

# %%
np.sum(groundtruth)# don't mind this slight variation
# Out:
# 1545.0

# %%
#now generate the ShanghaiB's ground truth
path_sets = [part_B_train,part_B_test]

# %%
img_paths = []
for path in path_sets:
    for img_path in glob.glob(os.path.join(path, '*.jpg')):
        img_paths.append(img_path)

# %%
for img_path in img_paths:
    print (img_path)
    mat = io.loadmat(img_path.replace('.jpg','.mat').replace('images','ground-truth').replace('IMG_','GT_IMG_'))
    img= plt.imread(img_path)
    k = np.zeros((img.shape[0],img.shape[1]))
    gt = mat["image_info"][0,0][0,0][0]
    for i in range(0,len(gt)):
        if int(gt[i][1])<img.shape[0] and int(gt[i][0])<img.shape[1]:
            k[int(gt[i][1]),int(gt[i][0])]=1
    k = gaussian_filter_density(k)
    with h5py.File(img_path.replace('.jpg','.h5').replace('images','ground-truth'), 'w') as hf:
            hf['density'] = k
# Out:
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_1.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_10.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_100.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_101.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_102.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_103.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_104.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_105.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_106.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_107.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_108.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_109.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_11.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_110.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_111.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_112.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_113.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_114.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_115.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_116.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_117.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_118.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_119.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_12.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_120.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_121.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_122.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_123.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_124.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_125.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_126.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_127.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_128.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_129.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_13.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_130.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_131.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_132.jpg
# (768, 1024)
# generate density...
# done.
# J:/python trails/ShanghaiTech_Crowd_Counting_Dataset/part_B_final/train_data/images\IMG_133.jpg
# (768, 1024)
# generate density...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-1aff5191dba1> in <module>
#       8         if int(gt[i][1])<img.shape[0] and int(gt[i][0])<img.shape[1]:
#       9             k[int(gt[i][1]),int(gt[i][0])]=1
# ---> 10     k = gaussian_filter_density(k)
#      11     with h5py.File(img_path.replace('.jpg','.h5').replace('images','ground-truth'), 'w') as hf:
#      12             hf['density'] = k
#
# <ipython-input-2-0e96deda649f> in gaussian_filter_density(gt)
#      22         else:
#      23             sigma = np.average(np.array(gt.shape))/2./2. #case: 1 point
# ---> 24         density += scipy.ndimage.filters.gaussian_filter(pt2d, sigma, mode='constant')
#      25     print ('done.')
#      26     return density
#
# K:\Anaconda3\lib\site-packages\scipy\ndimage\filters.py in gaussian_filter(input, sigma, order, output, mode, cval, truncate)
#     297         for axis, sigma, order, mode in axes:
#     298             gaussian_filter1d(input, sigma, axis, order, output,
# --> 299                               mode, cval, truncate)
#     300             input = output
#     301     else:
#
# K:\Anaconda3\lib\site-packages\scipy\ndimage\filters.py in gaussian_filter1d(input, sigma, axis, order, output, mode, cval, truncate)
#     215     # Since we are calling correlate, not convolve, revert the kernel
#     216     weights = _gaussian_kernel1d(sigma, order, lw)[::-1]
# --> 217     return correlate1d(input, weights, axis, output, mode, cval, 0)
#     218
#     219
#
# K:\Anaconda3\lib\site-packages\scipy\ndimage\filters.py in correlate1d(input, weights, axis, output, mode, cval, origin)
#      93     mode = _ni_support._extend_mode_to_code(mode)
#      94     _nd_image.correlate1d(input, weights, axis, output, mode, cval,
# ---> 95                           origin)
#      96     return output
#      97
#
# KeyboardInterrupt:
